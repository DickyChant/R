# %%
setwd("~/codes/R/")

# %%
inData <- read.table("rData/AQ_FSPMC_USEmbassy.csv",skip = 3,header = TRUE,sep = ",")

# %%
inData
# Out:
#      Time                Height ug.m3 Source   Status Method.ID
# 1    2019/01/01 00:00:00 0      61    AQ_USEMB -1     0
# 2    2019/01/01 01:00:00 0      57    AQ_USEMB -1     0
# 3    2019/01/01 02:00:00 0      52    AQ_USEMB -1     0
# 4    2019/01/01 03:00:00 0      52    AQ_USEMB -1     0
# 5    2019/01/01 04:00:00 0      46    AQ_USEMB -1     0
# 6    2019/01/01 05:00:00 0      48    AQ_USEMB -1     0
# 7    2019/01/01 06:00:00 0      50    AQ_USEMB -1     0
# 8    2019/01/01 07:00:00 0      54    AQ_USEMB -1     0
# 9    2019/01/01 08:00:00 0      53    AQ_USEMB -1     0
# 10   2019/01/01 09:00:00 0      54    AQ_USEMB -1     0
# 11   2019/01/01 10:00:00 0      45    AQ_USEMB -1     0
# 12   2019/01/01 11:00:00 0      24    AQ_USEMB -1     0
# 13   2019/01/01 12:00:00 0      22    AQ_USEMB -1     0
# 14   2019/01/01 13:00:00 0      13    AQ_USEMB -1     0
# 15   2019/01/01 14:00:00 0      21    AQ_USEMB -1     0
# 16   2019/01/01 15:00:00 0      17    AQ_USEMB -1     0
# ...

# %%
plot(inData$Height)
# Out:
# plot without title
